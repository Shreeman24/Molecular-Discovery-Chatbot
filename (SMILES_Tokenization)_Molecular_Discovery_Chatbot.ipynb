# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# <h2><b> SMILES tokenization assesses the Tokenizer subsystem on unconditional generation of SMILES and assesses the validity and Tanimoto similarity values. </b></h2>
#
# ---

# %% [markdown]
# # Install Libraries

# %%
# !pip install SmilesPE langchain ctransformers torch rdkit
# Out:
# Collecting SmilesPE
#   Downloading SmilesPE-0.0.3-py3-none-any.whl (15 kB)
# Collecting langchain
#   Downloading langchain-0.1.16-py3-none-any.whl (817 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.7/817.7 kB 7.9 MB/s eta 0:00:00
# Collecting ctransformers
#   Downloading ctransformers-0.2.27-py3-none-any.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 28.1 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Collecting rdkit
#   Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: fastprogress in /usr/local/lib/python3.10/dist-packages (from SmilesPE) (1.0.3)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from SmilesPE) (4.3.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.32 (from langchain)
#   Downloading langchain_community-0.0.34-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 69.1 MB/s eta 0:00:00
# Collecting langchain-core<0.2.0,>=0.1.42 (from langchain)
#   Downloading langchain_core-0.1.46-py3-none-any.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 23.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.50-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.5/115.5 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from ctransformers) (0.20.3)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.8 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.42->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.6 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim->SmilesPE) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->SmilesPE) (6.4.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->ctransformers) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: rdkit, packaging, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, jsonpointer, typing-inspect, nvidia-cusparse-cu12, nvidia-cudnn-cu12, marshmallow, jsonpatch, SmilesPE, nvidia-cusolver-cu12, langsmith, dataclasses-json, ctransformers, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed SmilesPE-0.0.3 ctransformers-0.2.27 dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.16 langchain-community-0.0.34 langchain-core-0.1.46 langchain-text-splitters-0.0.1 langsmith-0.1.50 marshmallow-3.21.1 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 orjson-3.10.1 packaging-23.2 rdkit-2023.9.5 typing-inspect-0.9.0

# %%
from transformers import BertTokenizerFast, BertLMHeadModel
checkpoint = 'unikei/bert-base-smiles'
bert_tokenizer = BertTokenizerFast.from_pretrained(checkpoint)
bert_model = BertLMHeadModel.from_pretrained(checkpoint)

# Initialize empty lists to store encoded inputs
input_ids_list = []
attention_mask_list = []

vocab_file_path = '/content/drive/MyDrive/LLama2HealthCareChatBot-master/SPE_ChEMBL.txt'
# Out:
# tokenizer_config.json:   0%|          | 0.00/315 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/306k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/777k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/638 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`

# %% [markdown]
# # Default SMILESPE Tokenizer

# %%
# SMILESPE Fragment Level Tokenizer
import codecs
from SmilesPE.tokenizer import *

def test_spe():
    vocab_file_path = '/content/drive/MyDrive/LLama2HealthCareChatBot-master/SPE_ChEMBL.txt'
    spe_vob= codecs.open(vocab_file_path)
    spe = SPE_Tokenizer(spe_vob)

    smi = 'CC(=O)Oc1ccccc1C(=O)O'
    smiles = spe.tokenize(smi)

    return smiles

# %% [markdown]
# # Update BERT Vocab List

# %%
def update_tokens(tokeniz, modell, vocab_file_path):
  # Update BERT tokens
  tokeniz.add_tokens(vocab_file_path)

  # Save the updated tokenizer
  tokeniz.save_pretrained(checkpoint)

  # If you modified the vocabulary file, make sure to load it in the model
  modell.resize_token_embeddings(len(tokeniz))

  # Save updated model
  modell.save_pretrained(checkpoint)

  return tokeniz, modell

# %% [markdown]
# # Chemical Validity Check Function (using RDKit)

# %%
from rdkit import Chem

def chemical_validity_check(smi, file_to_edit):
  m = Chem.MolFromSmiles(smi, sanitize=False)
  if m is None:
    print('invalid', file=file_to_edit)
    return 0
  else:
    print('valid', file=file_to_edit)
    return 1

# %% [markdown]
# # Perform Mask Tokenization

# %%
from transformers import BertLMHeadModel, BertTokenizerFast
import torch
from rdkit import Chem
from rdkit.Chem import AllChem
import random

def calculate_tanimoto_similarity(smiles1, smiles2):
    # Convert SMILES to RDKit molecules
    mol1 = Chem.MolFromSmiles(smiles1)
    mol2 = Chem.MolFromSmiles(smiles2)

    # Calculate Morgan fingerprints
    fp1 = AllChem.GetMorganFingerprint(mol1, 2)
    fp2 = AllChem.GetMorganFingerprint(mol2, 2)

    # Calculate Tanimoto similarity
    similarity = AllChem.DataStructs.TanimotoSimilarity(fp1, fp2)

    return similarity

def mask_tokenization_process_default(smiles, maximum_count, output_file):
    checkpoint = 'unikei/bert-base-smiles'
    tokenizer = BertTokenizerFast.from_pretrained(checkpoint)
    model = BertLMHeadModel.from_pretrained(checkpoint, is_decoder=True)

    vocab_file_path = '/content/drive/MyDrive/LLama2HealthCareChatBot-master/SPE_ChEMBL.txt'
    spe_vob= codecs.open(vocab_file_path)
    spe = SPE_Tokenizer(spe_vob)

    tokenizer, model = update_tokens(tokenizer, model, vocab_file_path)

    output = []

    print("SMILES Before:", smiles, file=output_file)

    # Tokenize the input
    input_ids = tokenizer.encode(smiles, return_tensors="pt")

    valid = False

    # Set max_count threshold of possible generations to avoid infinite loop
    actual_count = 0

    while (actual_count != maximum_count):  # Generate 1 sequence
        # Generate sequence
        output_sequences = model.generate(
            input_ids,
            max_new_tokens=1,
            do_sample=True,  # Enable sampling (to allow non-deterministic SMILES completion)
            pad_token_id=tokenizer.eos_token, # May have to use better fragment library with pairwise bracket
            output_hidden_states=True
        )

        # Decode the sequence
        decoded_sequence = tokenizer.decode(output_sequences[0], skip_special_tokens=True)

        # Extract the last token (to replace [MASK])
        token = output_sequences[0][-1].item()
        token_str = tokenizer.decode(token)

        # Tokenize input SMILES
        smi = spe.tokenize(smiles)

        tokenized_string = smi.split()
        token_index = random.randint(0, len(tokenized_string) - 1)
        token_to_replace = tokenized_string[token_index]
        print("Token To Replace:", token_to_replace, file=output_file)
        print("Tokenized String:", tokenized_string, file=output_file)

        # Replace the [MASK] token with the predicted token
        decoded_sequence = decoded_sequence.replace(token_to_replace, token_str)

        x = chemical_validity_check(decoded_sequence.replace(" ", ""), output_file)
        similarity = -1
        if x == 1:
            valid = True
            if (Chem.MolFromSmiles(decoded_sequence.replace(" ", "")) != None):
              similarity = calculate_tanimoto_similarity(smiles, decoded_sequence.replace(" ", ""))
        else:
            valid = False

        print("SMILES After: ", decoded_sequence, file=output_file)
        # Calculate the score for the generated sequence
        with torch.no_grad():
            logits = model.forward(input_ids=output_sequences, return_dict=True).logits
            softmax_scores = torch.softmax(logits[0, -1, :], dim=-1)  # Applying softmax to get probabilities
        score = softmax_scores.max().item()  # Taking the maximum probability as the score

        # Append sequence information to output
        output.append({
            "sequence": decoded_sequence,
            'validity': "valid" if valid else "invalid",
            'similarity': similarity,
            "score": score,
        })

        actual_count += 1

    return output

# %% [markdown]
# ## Generate pipeline to benchmark performance

# %%
import pandas as pd
import statistics

def assess_model_validity_similarity(validity_list, similarity_list):
    validity = output['validity']
    similarity = output['similarity']

def run_model_visualize(num_samples, maximum_count, output_file):
    train_dataset = pd.read_csv('/content/drive/MyDrive/LLama2HealthCareChatBot-master/data/BindingAffinity_data/binding_affinity_train.csv')
    smiles_list = list(train_dataset['Canonical SMILE'])

    validity_count = 0

    validity_list = []
    similarity_list = []

    with open(output_file, "a") as output_file:
      for i in range(num_samples):
          smiles = random.choice(smiles_list)
          output_list = mask_tokenization_process_default(smiles, maximum_count, output_file)
          print(output_list)
          for val in output_list:
            validity = val['validity']
            similarity = val['similarity']

            if (validity == 'valid'):
              validity_count += 1

            if similarity != -1:
                similarity_list.append(similarity)


          validity_list.append(validity_count/maximum_count)

    avg_validity = 0
    avg_similarity = 0
    print(validity_list)
    print(similarity_list)
    if (validity_list):
      avg_validity = statistics.mean(validity_list)
    if (similarity_list):
      avg_similarity = statistics.mean(similarity_list)

    return avg_validity, avg_similarity

# %% [markdown]
# ## Perform assessment of 100 SMILES generation from each of 20 random SMILES

# %%
validity, similarity = run_model_visualize(20, 100, 'output.txt')
# Out:
# [19:46:11] SMILES Parse Error: syntax error while parsing: ((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((
# [19:46:11] SMILES Parse Error: Failed parsing SMILES '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((' for input: '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)(('
# [19:46:12] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:12] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:13] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:13] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:13] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:13] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:14] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:14] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:15] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:15] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:16] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:16] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:17] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:17] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:17] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:17] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:18] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:18] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:19] SMILES Parse Error: syntax error while parsing: CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(
# [19:46:19] SMILES Parse Error: Failed parsing SMILES 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(' for input: 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C('
# [19:46:19] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:19] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:20] SMILES Parse Error: syntax error while parsing: ((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((
# [19:46:20] SMILES Parse Error: Failed parsing SMILES '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((' for input: '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)(('
# [19:46:20] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:20] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:21] SMILES Parse Error: syntax error while parsing: CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(
# [19:46:21] SMILES Parse Error: Failed parsing SMILES 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(' for input: 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C('
# [19:46:21] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:21] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:22] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:22] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:23] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:23] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:23] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:23] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:24] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:24] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:24] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:24] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:25] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:25] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:25] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:25] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:26] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:26] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:26] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:26] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:26] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:26] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:27] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:27] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:27] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:27] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:28] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:28] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:28] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:28] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:28] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:28] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:29] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:29] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:29] SMILES Parse Error: syntax error while parsing: CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(
# [19:46:29] SMILES Parse Error: Failed parsing SMILES 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(' for input: 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C('
# [19:46:29] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:29] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:30] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:30] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:30] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:30] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:31] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:31] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:31] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:31] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:31] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:31] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:32] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:32] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:32] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:32] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:32] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:32] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:33] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:33] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:33] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:33] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:34] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:34] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:34] SMILES Parse Error: syntax error while parsing: ((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((
# [19:46:34] SMILES Parse Error: Failed parsing SMILES '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((' for input: '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)(('
# [19:46:34] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:34] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:35] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:35] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:35] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:35] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:35] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:35] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:36] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:36] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:37] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:37] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:37] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:37] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:38] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:38] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:38] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:38] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:39] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:39] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:39] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:39] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:40] SMILES Parse Error: syntax error while parsing: CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(
# [19:46:40] SMILES Parse Error: Failed parsing SMILES 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(' for input: 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C('
# [19:46:40] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:40] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:41] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:41] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:41] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:41] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:41] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:41] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:42] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:42] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:42] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:42] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:42] SMILES Parse Error: syntax error while parsing: CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(
# [19:46:42] SMILES Parse Error: Failed parsing SMILES 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C(' for input: 'CC1(CC2C(CC3(CN(C4(CC(CC2(C34)C(C)C)N(C1)C('
# [19:46:43] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:43] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:43] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:43] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:44] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:44] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:44] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:44] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:44] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:44] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:45] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:45] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:45] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:45] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:45] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:45] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:46] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:46] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:46] SMILES Parse Error: syntax error while parsing: CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:46] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C((=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:47] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:47] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:47] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:47] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:47] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:47] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:48] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:48] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:48] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:48] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:48] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:48] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:49] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:49] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN((=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:49] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:49] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:50] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:50] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:50] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:50] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:51] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:51] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:51] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:51] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:52] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:52] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:52] SMILES Parse Error: syntax error while parsing: ((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((
# [19:46:52] SMILES Parse Error: Failed parsing SMILES '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((' for input: '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)(('
# [19:46:53] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:53] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:54] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:54] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:54] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:54] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:54] SMILES Parse Error: syntax error while parsing: ((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((
# [19:46:54] SMILES Parse Error: Failed parsing SMILES '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)((' for input: '((1=((2((((3=(N((4=((=((2=(34)((()()N((1)(('
# [19:46:55] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:55] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:55] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:55] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:56] SMILES Parse Error: syntax error while parsing: CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(
# [19:46:56] SMILES Parse Error: Failed parsing SMILES 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C(' for input: 'CC1=(C(CC3=CN(C4=CC=(=C34)C(C)C)N(C1)C('
# [19:46:56] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:56] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:56] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:56] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:57] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:57] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [19:46:57] SMILES Parse Error: syntax error while parsing: CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(
# [19:46:57] SMILES Parse Error: Failed parsing SMILES 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C(' for input: 'CC1=CC2C(CC3=CN(C4=CC=CC2=C34)C(C)C)N(C1)C('
# [{'sequence': '((1 = ((2( ( ((3 = (N ( (4 = (( = ((2 = (34 ) ( ( ( ) ( ) N ( (1 ) ( (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = (C ( CC3 = CN ( C4 = CC = ( = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = (C ( CC3 = CN ( C4 = CC = ( = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( ( = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = (C ( CC3 = CN ( C4 = CC = ( = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 ( CC2C ( CC3 ( CN ( C4 ( CC ( CC2 ( C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': '((1 = ((2( ( ((3 = (N ( (4 = (( = ((2 = (34 ) ( ( ( ) ( ) N ( (1 ) ( (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = (C ( CC3 = CN ( C4 = CC = ( = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 ( CC2C ( CC3 ( CN ( C4 ( CC ( CC2 ( C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( ( = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( ( = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( ( = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) N ( C1 ) C (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999562501907349}, {'sequence': 'CC1 = CC2C ( CC3 = CN ( C4 = CC = CC2 = C34 ) C ( C ) C ) ...
# [19:47:00] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:00] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:00] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:00] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:01] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F(
# [19:47:01] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F('
# [19:47:01] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:01] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:02] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F(
# [19:47:02] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F('
# [19:47:02] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)()C(=O)C2=CNC3=NC=C(C=C23)Cl)((
# [19:47:02] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)()C(=O)C2=CNC3=NC=C(C=C23)Cl)((' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)()C(=O)C2=CNC3=NC=C(C=C23)Cl)(('
# [19:47:03] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:03] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:03] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2
=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:10] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:10] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:11] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:11] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:11] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:11] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:12] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:12] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:12] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F(
# [19:47:12] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=(C3=NC=C(C=C23)Cl)F('
# [19:47:13] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:13] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:13] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:13] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:14] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:14] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:14] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:14] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:15] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:15] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:15] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:15] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:16] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:16] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:16] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:16] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:17] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:17] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:17] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:17] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:18] SMILES Parse Error: syntax error while parsing: (S(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:18] SMILES Parse Error: Failed parsing SMILES '(S(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: '(S(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:19] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:19] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:19] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:19] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:20] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:20] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:21] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(
# [19:47:21] SMILES Parse Error: Failed parsing SMILES 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F(' for input: 'CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2=CNC3=NC=C(C=C23)Cl)F('
# [19:47:22] SMILES Parse Error: syntax error while parsing: CCCS(=O)(=O)NC1=C(C(=C(C=C1)F)C(=O)C2
# [20:05:20] SMILES Parse Error: syntax error while parsing: C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2(
# [20:05:20] SMILES Parse Error: Failed parsing SMILES 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2(' for input: 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2('
# [20:05:20] SMILES Parse Error: syntax error while parsing: C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2(
# [20:05:20] SMILES Parse Error: Failed parsing SMILES 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2(' for input: 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2('
# [20:05:21] SMILES Parse Error: syntax error while parsing: C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2(
# [20:05:21] SMILES Parse Error: Failed parsing SMILES 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2(' for input: 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N2('
# [20:05:22] SMILES Parse Error: unclosed ring for input: 'C1=CC=C(C=C1)C2=NC(=C3C=CC(=O)C=C3)C(=C4C=CNC=C4)N21'
# [20:05:22] SMILES Parse Error: syntax error while parsing: C1===C(C=C1)C2=NC(=C3C==(=O)C=C3)C(=C4C=CNC=C4)N2=
# [20:05:22] SMILES Parse Error: Failed parsing SMILES 'C1===C(C=C1)C2=NC(=C3C==(=O)C=C3)C(=C4C=CNC=C4)N2=' for input: 'C1===C(C=C1)C2=NC(=C3C==(=O)C=C3)C(=C4C=CNC=C4)N2='
# [{'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) ( (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = (C = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 =', 'validity': 'invalid', 'similarity': -1, 'score': 0.992229163646698}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 C1C', 'validity': 'invalid', 'similarity': -1, 'score': 0.4905623197555542}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2C', 'validity': 'valid', 'similarity': 0.7142857142857143, 'score': 0.4778134822845459}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 C2', 'validity': 'invalid', 'similarity': -1, 'score': 0.9749044179916382}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = = = C ( C = C1 ) C2 = NC ( = C3C = = ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 =', 'validity': 'invalid', 'similarity': -1, 'score': 0.992229163646698}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2C1', 'validity': 'invalid', 'similarity': -1, 'score': 0.0834241658449173}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 (', 'validity': 'invalid', 'similarity': -1, 'score': 0.9999635219573975}, {'sequence': 'C1 = CC = C ( C = C1 ) C2 = NC ( = C3C = CC ( = O ) C = C3 ) C ( = C4C = CNC = C4 ) N2 =', 'validity':  ...
# [0.0, 0.0, 0.02, 0.02, 0.13, 0.31, 0.31, 0.31, 0.31, 0.31, 0.31, 0.31, 0.31, 0.32, 0.32, 0.38, 0.38, 0.39, 0.48, 0.52]
# [0.3783783783783784, 0.3273542600896861, 0.8548387096774194, 0.8346456692913385, 0.8346456692913385, 0.8548387096774194, 0.8346456692913385, 0.8548387096774194, 0.8548387096774194, 0.8153846153846154, 0.8548387096774194, 0.8346456692913385, 0.8548387096774194, 0.8346456692913385, 0.8346456692913385, 0.8548387096774194, 0.8346456692913385, 0.7956204379562044, 0.8548387096774194, 0.8346456692913385, 0.7019230769230769, 0.8222222222222222, 0.8222222222222222, 0.8021978021978022, 0.8505747126436781, 0.8222222222222222, 0.8818181818181818, 0.8346456692913385, 0.8346456692913385, 0.4161073825503356, 0.7956204379562044, 0.8346456692913385, 0.8346456692913385, 0.8548387096774194, 0.8153846153846154, 0.8346456692913385, 0.7142857142857143, 0.7142857142857143, 0.6896551724137931, 0.6896551724137931]

# %% [markdown]
# ## Observe Results

# %%
print("Validity Percentage:", validity*100)
print("Similarity Percentage: ", similarity*100)

# For 20 SMILES, each with 100 generations, we obtain validity of 0.3905 and similarity of 0.82891.
# Out:
# Validity Percentage: 27.200000000000003
# Similarity Percentage:  78.49713607308159

# %%
with open('output.txt', "a") as output_file:
    print("Average Validity: ", validity, file=output_file)
    print("Average Similarity: ", similarity, file=output_file)

# %% [markdown]
# # Additional Notes and Comments
#
# > Could Explore SEFLIES tokenization as Future Development

# %%
# EXTRA NOTES ON IMPLEMENTATION OF PROJECT
"""
                       Inpainting              |            Generation
                       (edit)

Unconditional          [Validity, Similarity]  |        [Validity, Similarity]

Conditional            [Success]               |            {Success}

We can move anticlockwise from the top right quadrant in shaping the decision-making process / direction for the thesis
At each step, you highlight challenges (representing proteins, making Q&A prompts, limitations on token size, finding educational assessments that fit college-level chemistry questions).

Thesis Format
- Results and discussion of results could be a section of each chapter
- Each subsection breaks down the results and the storyline flows (like the research discovery process, the challenges faced)

Example: orphaned parentheses does not satisfy my style of inpainting. This is a challenge. To solve this partially, we explored SELFIES. There are benefits with SELFIES ...
         If SELFIES does not work, you don't have to find a solution depending on time constraints. You can say there needs to be more work done to improve small molecule representation by ... and leave to other.
"""
# Out:
#   File "<ipython-input-1-d553d348becf>", line 3
#     Inpainting              |            Generation
#     ^
# IndentationError: unexpected indent
